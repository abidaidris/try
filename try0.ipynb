# %%
print (" First Program")
name = "Abida Idris"
age = 45
status = "Professional"
jtitle = "asst Professor"
city = "lahore"
print ("My name is ", name)
print ("My age is ", age)
print ("My working status  is ",status)
print ("My job title is ", jtitle)
print ("my city is ", city)
# Out:
#  First Program
# My name is  Abida Idris
# My age is  45
# My working status  is  Professional
# My job title is  asst Professor
# my city is  lahore
